# %% [markdown]
# Imports for Local

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import optuna, joblib, matplotlib, os, pyfolio, sys
from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from pyfolio import timeseries

matplotlib.use('Agg')
# %matplotlib inline
import datetime
from stockstats import StockDataFrame as Sdf
from QuantumAI.config import config
from QuantumAI.config import config_tickers
from QuantumAI.preprocessors.yahoodownloader import YahooDownloader
from QuantumAI.preprocessors.preprocessors import FeatureEngineer, data_split
# from QuantumAI.env.env_portfolio import StockPortfolioEnv
# from QuantumAI.env.env_portfolioSPX import StockPortfolioEnv
from QuantumAI.env.env_portfolio_original import StockPortfolioEnv
from QuantumAI.env.env_portfolioSPXvsCash import SPXvsCASH
from QuantumAI.models.models import DRLAgent
from QuantumAI.plot.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts, show_weight_distribution
from QuantumAI.preprocessors.data_processor import DataProcessor
from QuantumAI.preprocessors.processor_yahoofinance import YahooFinanceProcessor
from QuantumAI.hyper_opt.hyperopt1 import optimize

# %%
spx = pd.read_csv("/Users/floriankockler/My Drive/SPX_2.csv", skiprows=6)
spx['date'] = pd.to_datetime(spx["date"], format='%m/%d/%Y')
spx
# Out:
#            date    close     open      low     high  RSI14  RSI30   RSI3  \
# 0    1990-01-02   359.69   353.39   351.98   359.69  66.90  66.57    NaN
# 1    1990-01-03   358.76   359.66   357.89   360.59  64.92  65.48  88.64
# 2    1990-01-04   355.67   358.74   352.89   358.76  58.72  61.98  56.59
# 3    1990-01-05   352.20   355.65   351.35   355.67  52.64  58.36  35.17
# 4    1990-01-08   353.79   352.19   350.54   354.24  54.94  59.48  48.55
# ...         ...      ...      ...      ...      ...    ...    ...    ...
# 8450 2023-07-19  4565.72  4563.87  4557.48  4578.43  75.00  67.61  94.86
# 8451 2023-07-20  4534.87  4554.38  4527.56  4564.74  67.94  64.81  53.04
# 8452 2023-07-21  4536.34  4550.16  4535.79  4555.00  68.09  64.88  54.47
# 8453 2023-07-24  4554.64  4543.39  4541.29  4563.41  70.02  65.78  71.01
# 8454 2023-07-25  4576.77  4555.19  4552.42  4580.62  72.22  66.84  82.52
#
#         MA200     MA50     MA20  tic
# 0      331.86   344.05   349.02  SPX
# 1      332.20   344.28   349.39  SPX
# 2      332.52   344.49   349.69  SPX
# 3      332.83   344.66   349.88  SPX
# 4      333.16   344.89   350.19  SPX
# ...       ...      ...      ...  ...
# 8450  4043.67  4311.72  4435.98  SPX
# 8451  4048.41  4319.65  4444.44  SPX
# 8452  4052.70  4327.99  4452.17  SPX
# 8453  4056.52  4336.33  4462.48  SPX
# 8454  4060.49  4345.26  4474.88  SPX
#
# [8455 rows x 12 columns]

# %%
ndx = pd.read_csv("/Users/floriankockler/My Drive/NDX_2.csv", skiprows=6)
ndx['date'] = pd.to_datetime(ndx["date"], format='%m/%d/%Y')
ndx
# Out:
#            date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0    1990-01-02    227.73    223.84    220.44    227.73  64.06  56.79    NaN
# 1    1990-01-03    226.10    227.73    226.10    228.94  60.09  54.71  71.55
# 2    1990-01-04    224.72    226.10    222.71    226.18  56.87  53.01  52.56
# 3    1990-01-05    223.14    224.72    222.89    224.80  53.35  51.13  36.11
# 4    1990-01-08    223.54    223.14    221.64    223.58  54.12  51.58  42.90
# ...         ...       ...       ...       ...       ...    ...    ...    ...
# 8450 2023-07-19  15826.35  15888.16  15781.96  15932.05  75.50  69.99  91.29
# 8451 2023-07-20  15466.09  15717.67  15429.87  15771.84  60.26  63.23  29.71
# 8452 2023-07-21  15425.67  15554.96  15410.57  15600.54  58.82  62.53  26.69
# 8453 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 8454 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
#
#          MA200      MA50      MA20  tic
# 0       213.82    221.50    219.75  NDX
# 1       214.06    221.40    219.72  NDX
# 2       214.27    221.32    219.59  NDX
# 3       214.48    221.26    219.54  NDX
# 4       214.69    221.18    219.48  NDX
# ...        ...       ...       ...  ...
# 8450  12589.11  14562.17  15202.46  NDX
# 8451  12611.59  14605.66  15232.39  NDX
# 8452  12632.57  14650.15  15251.56  NDX
# 8453  12651.90  14692.16  15279.39  NDX
# 8454  12672.00  14736.23  15324.61  NDX
#
# [8455 rows x 12 columns]

# %%
combined = pd.concat([spx, ndx], axis=0)
combined = combined.sort_values(['date','tic'], ignore_index=True)
combined
# Out:
#             date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0     1990-01-02    227.73    223.84    220.44    227.73  64.06  56.79    NaN
# 1     1990-01-02    359.69    353.39    351.98    359.69  66.90  66.57    NaN
# 2     1990-01-03    226.10    227.73    226.10    228.94  60.09  54.71  71.55
# 3     1990-01-03    358.76    359.66    357.89    360.59  64.92  65.48  88.64
# 4     1990-01-04    224.72    226.10    222.71    226.18  56.87  53.01  52.56
# ...          ...       ...       ...       ...       ...    ...    ...    ...
# 16905 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 16906 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 16907 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 16908 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 16909 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#           MA200      MA50      MA20  tic
# 0        213.82    221.50    219.75  NDX
# 1        331.86    344.05    349.02  SPX
# 2        214.06    221.40    219.72  NDX
# 3        332.20    344.28    349.39  SPX
# 4        214.27    221.32    219.59  NDX
# ...         ...       ...       ...  ...
# 16905   4052.70   4327.99   4452.17  SPX
# 16906  12651.90  14692.16  15279.39  NDX
# 16907   4056.52   4336.33   4462.48  SPX
# 16908  12672.00  14736.23  15324.61  NDX
# 16909   4060.49   4345.26   4474.88  SPX
#
# [16910 rows x 12 columns]

# %%
eco = pd.read_csv("/Users/floriankockler/My Drive/eco.csv", skiprows=6)
eco['date'] = pd.to_datetime(eco["date"], format='%m/%d/%Y')
eco
# Out:
#            date  PUT Index  RXM Index  USGG2YR Index  USGG10YR Index  \
# 0    1990-01-02     133.84     137.01         7.8750          7.9300
# 1    1990-01-03     133.87     137.26         7.9270          7.9740
# 2    1990-01-04     133.72     136.81         7.9100          7.9720
# 3    1990-01-05     133.28     136.37         7.8850          7.9840
# 4    1990-01-08     133.76     136.69         7.8930          8.0120
# ...         ...        ...        ...            ...             ...
# 8751 2023-07-19    2574.82    1504.89         4.7660          3.7483
# 8752 2023-07-20    2575.25    1498.58         4.8387          3.8503
# 8753 2023-07-21    2572.36    1495.57         4.8372          3.8349
# 8754 2023-07-24    2579.06    1499.08         4.9191          3.8725
# 8755 2023-07-25    2582.45    1501.63         4.8827          3.9023
#
#       MOVE Index  VIX Index  NWHLSENY Index  NWHLSEND Index  USGG5YR Index  \
# 0          91.73      17.24            0.95            0.78         7.8470
# 1          93.21      18.19            0.94            0.80         7.9110
# 2          95.09      19.22            0.82            0.64         7.9000
# 3          85.28      20.11            0.83            0.73         7.8960
# 4          86.91      20.26            0.59            0.67         7.9070
# ...          ...        ...             ...             ...            ...
# 8751      107.19      13.76            0.96            0.70         3.9855
# 8752      112.85      13.99            0.92            0.49         4.1017
# 8753      106.66      13.60            0.94            0.55         4.0930
# 8754      109.95      13.91            0.92            0.37         4.1515
# 8755      109.95      14.04            0.92            0.37         4.1818
#
#       SFFRNEWS Index  US10-US2Y
# 0           0.031309     0.0550
# 1           0.033682     0.0470
# 2           0.025195     0.0620
# 3           0.047431     0.0990
# 4           0.072032     0.1190
# ...              ...        ...
# 8751       -0.017261    -1.0177
# 8752       -0.018575    -0.9884
# 8753       -0.010344    -1.0023
# 8754       -0.004883    -1.0466
# 8755       -0.004883    -0.9804
#
# [8756 rows x 12 columns]

# %%
df_merged = combined.merge(eco, on='date', how='left')
df_merged
# Out:
#             date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0     1990-01-02    227.73    223.84    220.44    227.73  64.06  56.79    NaN
# 1     1990-01-02    359.69    353.39    351.98    359.69  66.90  66.57    NaN
# 2     1990-01-03    226.10    227.73    226.10    228.94  60.09  54.71  71.55
# 3     1990-01-03    358.76    359.66    357.89    360.59  64.92  65.48  88.64
# 4     1990-01-04    224.72    226.10    222.71    226.18  56.87  53.01  52.56
# ...          ...       ...       ...       ...       ...    ...    ...    ...
# 16905 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 16906 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 16907 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 16908 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 16909 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#           MA200      MA50  ...  RXM Index USGG2YR Index  USGG10YR Index  \
# 0        213.82    221.50  ...     137.01        7.8750          7.9300
# 1        331.86    344.05  ...     137.01        7.8750          7.9300
# 2        214.06    221.40  ...     137.26        7.9270          7.9740
# 3        332.20    344.28  ...     137.26        7.9270          7.9740
# 4        214.27    221.32  ...     136.81        7.9100          7.9720
# ...         ...       ...  ...        ...           ...             ...
# 16905   4052.70   4327.99  ...    1495.57        4.8372          3.8349
# 16906  12651.90  14692.16  ...    1499.08        4.9191          3.8725
# 16907   4056.52   4336.33  ...    1499.08        4.9191          3.8725
# 16908  12672.00  14736.23  ...    1501.63        4.8827          3.9023
# 16909   4060.49   4345.26  ...    1501.63        4.8827          3.9023
#
#        MOVE Index  VIX Index  NWHLSENY Index  NWHLSEND Index  USGG5YR Index  \
# 0           91.73      17.24            0.95            0.78         7.8470
# 1           91.73      17.24            0.95            0.78         7.8470
# 2           93.21      18.19            0.94            0.80         7.9110
# 3           93.21      18.19            0.94            0.80         7.9110
# 4           95.09      19.22            0.82            0.64         7.9000
# ...           ...        ...             ...             ...            ...
# 16905      106.66      13.60            0.94            0.55         4.0930
# 16906      109.95      13.91            0.92            0.37         4.1515
# 16907      109.95      13.91            0.92            0.37         4.1515
# 16908      109.95      14.04            0.92            0.37         4.1818
# 16909      109.95      14.04            0.92            0.37         4.1818
#
#        SFFRNEWS Index  US10-US2Y
# 0            0.031309     0.0550
# 1            0.031309     0.0550
# 2            0.033682     0.0470
# 3            0.033682     0.0470
# 4            0.025195     0.0620
# ...               ...        ...
# 16905       -0.010344    -1.0023
# 16906       -0.004883    -1.0466
# 16907       -0.004883    -1.0466
# 16908       -0.004883    -0.9804
# 16909       -0.004883    -0.9804
#
# [16910 rows x 23 columns]

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

cleaned = fe.preprocess_data(df_merged)

df =cleaned.dropna(axis=0)
df.isna().sum()
df
# Out:
# Successfully added technical indicators
#             date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0     1990-01-02    227.73    223.84    220.44    227.73  64.06  56.79  71.55
# 8455  1990-01-02    359.69    353.39    351.98    359.69  66.90  66.57  71.55
# 1     1990-01-03    226.10    227.73    226.10    228.94  60.09  54.71  71.55
# 8456  1990-01-03    358.76    359.66    357.89    360.59  64.92  65.48  88.64
# 2     1990-01-04    224.72    226.10    222.71    226.18  56.87  53.01  52.56
# ...          ...       ...       ...       ...       ...    ...    ...    ...
# 16907 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 8453  2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 16908 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 8454  2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 16909 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#           MA200      MA50  ...  SFFRNEWS Index US10-US2Y        macd  \
# 0        213.82    221.50  ...        0.031309    0.0550    0.000000
# 8455     331.86    344.05  ...        0.031309    0.0550    0.000000
# 1        214.06    221.40  ...        0.033682    0.0470   -0.036571
# 8456     332.20    344.28  ...        0.033682    0.0470   -0.020865
# 2        214.27    221.32  ...        0.025195    0.0620   -0.089392
# ...         ...       ...  ...             ...       ...         ...
# 16907   4052.70   4327.99  ...       -0.010344   -1.0023   61.647135
# 8453   12651.90  14692.16  ...       -0.004883   -1.0466  257.405842
# 16908   4056.52   4336.33  ...       -0.004883   -1.0466   61.499949
# 8454   12672.00  14736.23  ...       -0.004883   -0.9804  250.099106
# 16909   4060.49   4345.26  ...       -0.004883   -0.9804   62.449134
#
#             boll_ub       boll_lb     rsi_30      cci_30       dx_30  \
# 0        229.220168    224.609832   0.000000   66.666667  100.000000
# 8455     229.220168    224.609832   0.000000   66.666667  100.000000
# 1        229.220168    224.609832   0.000000   66.666667  100.000000
# 8456     360.540219    357.909781   0.000000   66.666667  100.000000
# 2        229.196792    223.169875   0.000000  -76.898982   49.935797
# ...             ...           ...        ...         ...         ...
# 16907   4594.093122   4310.236878  64.877680  130.895366   39.904326
# 8453   15916.201353  14642.568647  62.769705   73.110558   20.580513
# 16908   4602.610732   4322.350268  65.775789  130.724267   41.563408
# 8454   15911.393328  14737.821672  64.284144   96.167351   26.033977
# 16909   4608.960684   4340.795316  66.836649  135.672047   44.891475
#
#        close_30_sma  close_60_sma
# 0        227.730000    227.730000
# 8455     359.690000    359.690000
# 1        226.915000    226.915000
# 8456     359.225000    359.225000
# 2        226.183333    226.183333
# ...             ...           ...
# 16907   4422.944667   4293.225333
# 8453   15164.923333  14441.190833
# 16908   4431.635000   4301.536167
# 8454   15200.427000  14481.748167
# 16909   4440.898667   4308.893167
#
# [16910 rows x 31 columns]

# %%
# df_combined = pd.concat([test, test_dx], axis=0)
# df_combined = df_combined.sort_values(['date','tic'], ignore_index=True)
# df_combined
# trial = fe.preprocess_data(df_combined)
# trial

# %%
#!SPäter BBG clean data class machen
# fe = FeatureEngineer(
#                     use_technical_indicator=True,
#                     use_turbulence=False,
#                     user_defined_feature = False)

# df = fe.clean_data(frame)
# df = df.dropna(axis=0)
# df["date"] = pd.to_datetime(df["date"])

bbg_full_start_date="1991-01-02"
full_end_date="2023-07-25"
bbg_train_start_date="1991-01-02"
bbg_train_end_date="2015-12-31"
bbg_validate_start_date="2016-01-01"
bbg_validate_end_date="2020-12-31"
bbg_test_start_date="2021-01-01"
bbg_test_end_date="2023-07-25"
bbg_ticker =["SPX Index"]

# %% [markdown]
# Imports for Colab

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import optuna, joblib, matplotlib
# from stable_baselines3 import A2C
# from stable_baselines3.common.evaluation import evaluate_policy

# matplotlib.use('Agg')
# %matplotlib inline
# import datetime
# from stockstats import StockDataFrame as Sdf
# from quantumai.config import config
# from quantumai.config import config_tickers
# from quantumai.preprocessors.yahoodownloader import YahooDownloader
# from quantumai.preprocessors.preprocessors import FeatureEngineer, data_split
# from quantumai.env.env_portfolio import StockPortfolioEnv
# from quantumai.models.models import DRLAgent
# from quantumai.plot.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
# from quantumai.preprocessors.data_processor import DataProcessor
# from quantumai.preprocessors.processor_yahoofinance import YahooFinanceProcessor
# import sys
# sys.path.append("../FinRL-Library")
# sys.path.append("../quantumai")

# %%
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
df.columns
# Out:
# Index(['date', 'close', 'open', 'low', 'high', 'RSI14', 'RSI30', 'RSI3',
#        'MA200', 'MA50', 'MA20', 'tic', 'PUT Index', 'RXM Index',
#        'USGG2YR Index', 'USGG10YR Index', 'MOVE Index', 'VIX Index',
#        'NWHLSENY Index', 'NWHLSEND Index', 'USGG5YR Index', 'SFFRNEWS Index',
#        'US10-US2Y', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30',
#        'close_30_sma', 'close_60_sma'],
#       dtype='object')

# %%
# dp = YahooFinanceProcessor()
# df = dp.download_data_flo(start_date=full_start_date, end_date=full_end_date, ticker_list=etf_list, time_interval="1D")
# df = df.rename(columns={"timestamp":"date"})

# %%
df.index = df.date.factorize()[0]
df
# Out:
#            date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0    1990-01-02    227.73    223.84    220.44    227.73  64.06  56.79  71.55
# 0    1990-01-02    359.69    353.39    351.98    359.69  66.90  66.57  71.55
# 1    1990-01-03    226.10    227.73    226.10    228.94  60.09  54.71  71.55
# 1    1990-01-03    358.76    359.66    357.89    360.59  64.92  65.48  88.64
# 2    1990-01-04    224.72    226.10    222.71    226.18  56.87  53.01  52.56
# ...         ...       ...       ...       ...       ...    ...    ...    ...
# 8452 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 8453 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 8453 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 8454 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 8454 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#          MA200      MA50  ...  SFFRNEWS Index US10-US2Y        macd  \
# 0       213.82    221.50  ...        0.031309    0.0550    0.000000
# 0       331.86    344.05  ...        0.031309    0.0550    0.000000
# 1       214.06    221.40  ...        0.033682    0.0470   -0.036571
# 1       332.20    344.28  ...        0.033682    0.0470   -0.020865
# 2       214.27    221.32  ...        0.025195    0.0620   -0.089392
# ...        ...       ...  ...             ...       ...         ...
# 8452   4052.70   4327.99  ...       -0.010344   -1.0023   61.647135
# 8453  12651.90  14692.16  ...       -0.004883   -1.0466  257.405842
# 8453   4056.52   4336.33  ...       -0.004883   -1.0466   61.499949
# 8454  12672.00  14736.23  ...       -0.004883   -0.9804  250.099106
# 8454   4060.49   4345.26  ...       -0.004883   -0.9804   62.449134
#
#            boll_ub       boll_lb     rsi_30      cci_30       dx_30  \
# 0       229.220168    224.609832   0.000000   66.666667  100.000000
# 0       229.220168    224.609832   0.000000   66.666667  100.000000
# 1       229.220168    224.609832   0.000000   66.666667  100.000000
# 1       360.540219    357.909781   0.000000   66.666667  100.000000
# 2       229.196792    223.169875   0.000000  -76.898982   49.935797
# ...            ...           ...        ...         ...         ...
# 8452   4594.093122   4310.236878  64.877680  130.895366   39.904326
# 8453  15916.201353  14642.568647  62.769705   73.110558   20.580513
# 8453   4602.610732   4322.350268  65.775789  130.724267   41.563408
# 8454  15911.393328  14737.821672  64.284144   96.167351   26.033977
# 8454   4608.960684   4340.795316  66.836649  135.672047   44.891475
#
#       close_30_sma  close_60_sma
# 0       227.730000    227.730000
# 0       359.690000    359.690000
# 1       226.915000    226.915000
# 1       359.225000    359.225000
# 2       226.183333    226.183333
# ...            ...           ...
# 8452   4422.944667   4293.225333
# 8453  15164.923333  14441.190833
# 8453   4431.635000   4301.536167
# 8454  15200.427000  14481.748167
# 8454   4440.898667   4308.893167
#
# [16910 rows x 31 columns]

# %%
df = df.sort_values(by=["tic", "date"])
df
stock = Sdf.retype(df.copy())
stock
unique_ticker = stock.tic.unique()
unique_ticker
# Out:
# array(['NDX', 'SPX'], dtype=object)

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values
  cov_list.append(covs)


df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df
# Out:
#             date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0     1990-12-31    200.53    199.37    198.39    200.53  61.89  57.60  59.92
# 1     1990-12-31    330.22    328.71    327.50    330.23  59.06  55.75  60.85
# 2     1991-01-02    199.77    200.53    199.04    200.80  59.55  56.80  43.39
# 3     1991-01-02    326.45    330.20    326.45    330.75  51.04  52.78  25.54
# 4     1991-01-03    196.40    199.77    196.16    199.80  50.46  53.39  15.31
# ...          ...       ...       ...       ...       ...    ...    ...    ...
# 16401 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 16402 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 16403 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 16404 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 16405 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#           MA200      MA50  ...        macd       boll_ub       boll_lb  \
# 0        206.27    188.69  ...    3.202235    203.287066    194.326934
# 1        334.29    319.46  ...    2.924538    332.631558    324.867442
# 2        206.17    189.19  ...    2.998350    203.084732    195.053268
# 3        334.20    319.74  ...    2.504065    332.269105    325.464895
# 4        206.06    189.55  ...    2.535609    202.994417    195.222583
# ...         ...       ...  ...         ...           ...           ...
# 16401   4052.70   4327.99  ...   61.647135   4594.093122   4310.236878
# 16402  12651.90  14692.16  ...  257.405842  15916.201353  14642.568647
# 16403   4056.52   4336.33  ...   61.499949   4602.610732   4322.350268
# 16404  12672.00  14736.23  ...  250.099106  15911.393328  14737.821672
# 16405   4060.49   4345.26  ...   62.449134   4608.960684   4340.795316
#
#           rsi_30      cci_30      dx_30  close_30_sma  close_60_sma  \
# 0      57.597757   66.601015  18.220983    194.914333    185.697333
# 1      55.748933   60.380411   7.442287    324.969667    316.762167
# 2      56.796107   64.214464  19.192477    195.408000    186.054000
# 3      52.782480   39.120709   3.249934    325.280667    317.011333
# 4      53.387634   28.543660   4.973436    195.720000    186.334667
# ...          ...         ...        ...           ...           ...
# 16401  64.877680  130.895366  39.904326   4422.944667   4293.225333
# 16402  62.769705   73.110558  20.580513  15164.923333  14441.190833
# 16403  65.775789  130.724267  41.563408   4431.635000   4301.536167
# 16404  64.284144   96.167351  26.033977  15200.427000  14481.748167
# 16405  66.836649  135.672047  44.891475   4440.898667   4308.893167
#
#                                                 cov_list  \
# 0      [[0.00018546693822883993, 0.000119093241522192...
# 1      [[0.00018546693822883993, 0.000119093241522192...
# 2      [[0.00018533093497689402, 0.000119181747471572...
# 3      [[0.00018533093497689402, 0.000119181747471572...
# 4      [[0.00018628025157379805, 0.000119883770228491...
# ...                                                  ...
# 16401  [[0.00025269533527981687, 0.000180749914571345...
# 16402  [[0.00025197081439871704, 0.000180258717847284...
# 16403  [[0.00025197081439871704, 0.000180258717847284...
# 16404  [[0.00025086874030817355, 0.000179662211125842...
# 16405  [[0.00025086874030817355, 0.000179662211125842...
#
#                                              return_list
# 0      tic              NDX       SPX
# date           ...
# 1      tic              NDX       SPX
# date           ...
# 2      tic              NDX       SPX
# date           ...
# 3      tic              NDX       SPX
# date           ...
# 4      tic              NDX       SPX
# date           ...
# ...                                                  ...
# 16401  tic              NDX       SPX
# date           ...
# 16402  tic              NDX       SPX
# date           ...
# 16403  tic              NDX       SPX
# date           ...
# 16404  tic              NDX       SPX
# date           ...
# 16405  tic              NDX       SPX
# date           ...
#
# [16406 rows x 33 columns]

# %%
df.to_csv("dftopoptimuze.csv")

# %%
loadeddf = pd.read_csv("dftopoptimuze.csv")
loadeddf.drop(columns=['Unnamed: 0'], inplace=True)
loadeddf["date"] = pd.to_datetime(loadeddf["date"])

# %%
df
# Out:
#             date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0     1990-12-31    200.53    199.37    198.39    200.53  61.89  57.60  59.92
# 1     1990-12-31    330.22    328.71    327.50    330.23  59.06  55.75  60.85
# 2     1991-01-02    199.77    200.53    199.04    200.80  59.55  56.80  43.39
# 3     1991-01-02    326.45    330.20    326.45    330.75  51.04  52.78  25.54
# 4     1991-01-03    196.40    199.77    196.16    199.80  50.46  53.39  15.31
# ...          ...       ...       ...       ...       ...    ...    ...    ...
# 16401 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 16402 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 16403 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 16404 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 16405 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#           MA200      MA50  ...        macd       boll_ub       boll_lb  \
# 0        206.27    188.69  ...    3.202235    203.287066    194.326934
# 1        334.29    319.46  ...    2.924538    332.631558    324.867442
# 2        206.17    189.19  ...    2.998350    203.084732    195.053268
# 3        334.20    319.74  ...    2.504065    332.269105    325.464895
# 4        206.06    189.55  ...    2.535609    202.994417    195.222583
# ...         ...       ...  ...         ...           ...           ...
# 16401   4052.70   4327.99  ...   61.647135   4594.093122   4310.236878
# 16402  12651.90  14692.16  ...  257.405842  15916.201353  14642.568647
# 16403   4056.52   4336.33  ...   61.499949   4602.610732   4322.350268
# 16404  12672.00  14736.23  ...  250.099106  15911.393328  14737.821672
# 16405   4060.49   4345.26  ...   62.449134   4608.960684   4340.795316
#
#           rsi_30      cci_30      dx_30  close_30_sma  close_60_sma  \
# 0      57.597757   66.601015  18.220983    194.914333    185.697333
# 1      55.748933   60.380411   7.442287    324.969667    316.762167
# 2      56.796107   64.214464  19.192477    195.408000    186.054000
# 3      52.782480   39.120709   3.249934    325.280667    317.011333
# 4      53.387634   28.543660   4.973436    195.720000    186.334667
# ...          ...         ...        ...           ...           ...
# 16401  64.877680  130.895366  39.904326   4422.944667   4293.225333
# 16402  62.769705   73.110558  20.580513  15164.923333  14441.190833
# 16403  65.775789  130.724267  41.563408   4431.635000   4301.536167
# 16404  64.284144   96.167351  26.033977  15200.427000  14481.748167
# 16405  66.836649  135.672047  44.891475   4440.898667   4308.893167
#
#                                                 cov_list  \
# 0      [[0.00018546693822883993, 0.000119093241522192...
# 1      [[0.00018546693822883993, 0.000119093241522192...
# 2      [[0.00018533093497689402, 0.000119181747471572...
# 3      [[0.00018533093497689402, 0.000119181747471572...
# 4      [[0.00018628025157379805, 0.000119883770228491...
# ...                                                  ...
# 16401  [[0.00025269533527981687, 0.000180749914571345...
# 16402  [[0.00025197081439871704, 0.000180258717847284...
# 16403  [[0.00025197081439871704, 0.000180258717847284...
# 16404  [[0.00025086874030817355, 0.000179662211125842...
# 16405  [[0.00025086874030817355, 0.000179662211125842...
#
#                                              return_list
# 0      tic              NDX       SPX
# date           ...
# 1      tic              NDX       SPX
# date           ...
# 2      tic              NDX       SPX
# date           ...
# 3      tic              NDX       SPX
# date           ...
# 4      tic              NDX       SPX
# date           ...
# ...                                                  ...
# 16401  tic              NDX       SPX
# date           ...
# 16402  tic              NDX       SPX
# date           ...
# 16403  tic              NDX       SPX
# date           ...
# 16404  tic              NDX       SPX
# date           ...
# 16405  tic              NDX       SPX
# date           ...
#
# [16406 rows x 33 columns]

# %%
train = data_split(df, bbg_train_start_date, bbg_train_end_date)
validate = data_split(df, bbg_validate_start_date, bbg_validate_end_date)
test = data_split(df, bbg_test_start_date, bbg_test_end_date)

# %%
train
# Out:
#            date    close     open      low     high  RSI14  RSI30   RSI3  \
# 0    1991-01-02   199.77   200.53   199.04   200.80  59.55  56.80  43.39
# 0    1991-01-02   326.45   330.20   326.45   330.75  51.04  52.78  25.54
# 1    1991-01-03   196.40   199.77   196.16   199.80  50.46  53.39  15.31
# 1    1991-01-03   321.91   326.46   321.90   326.53  43.40  49.50  12.47
# 2    1991-01-04   196.83   196.40   195.67   198.08  51.48  53.75  24.64
# ...         ...      ...      ...      ...      ...    ...    ...    ...
# 6296 2015-12-28  2056.50  2057.77  2044.20  2057.77  50.62  50.71  59.76
# 6297 2015-12-29  4691.08  4645.08  4644.32  4702.74  56.91  54.95  86.73
# 6297 2015-12-29  2078.36  2060.54  2060.54  2081.56  54.96  52.85  78.45
# 6298 2015-12-30  4652.01  4687.16  4651.73  4688.66  52.97  53.14  56.74
# 6298 2015-12-30  2063.36  2077.34  2061.97  2077.34  51.61  51.27  53.08
#
#         MA200     MA50  ...      macd      boll_ub      boll_lb     rsi_30  \
# 0      206.17   189.19  ...  2.998350   203.084732   195.053268  56.796107
# 0      334.20   319.74  ...  2.504065   332.269105   325.464895  52.782480
# 1      206.06   189.55  ...  2.535609   202.994417   195.222583  53.387634
# 1      334.10   319.88  ...  1.783934   333.141944   324.148056  49.501121
# 2      205.97   189.92  ...  2.178470   203.016094   194.980906  53.753968
# ...       ...      ...  ...       ...          ...          ...        ...
# 6296  2061.49  2065.14  ... -4.428211  2106.573325  2001.876675  50.713085
# 6297  4472.99  4626.90  ...  2.532235  4746.436586  4510.665414  54.950690
# 6297  2061.48  2066.04  ... -1.770284  2106.262560  2001.982440  52.849490
# 6298  4474.37  4630.69  ...  4.757756  4736.490657  4514.196343  53.141166
# 6298  2061.43  2066.63  ... -0.864269  2099.328415  2004.989585  51.271895
#
#          cci_30      dx_30  close_30_sma  close_60_sma  \
# 0     64.214464  19.192477    195.408000    186.054000
# 0     39.120709   3.249934    325.280667    317.011333
# 1     28.543660   4.973436    195.720000    186.334667
# 1    -24.893497  12.555330    325.366333    317.151833
# 2     15.716780   2.744251    196.170667    186.721333
# ...         ...        ...           ...           ...
# 6296 -25.136480   8.777923   2060.662333   2053.974667
# 6297  71.475191   0.833402   4635.317333   4582.929667
# 6297  39.320468   2.873594   2062.506333   2056.091333
# 6298  43.969731   0.833402   4638.202000   4588.272667
# 6298  16.730696   2.873594   2062.845333   2057.363167
#
#                                                cov_list  \
# 0     [[0.00018533093497689402, 0.000119181747471572...
# 0     [[0.00018533093497689402, 0.000119181747471572...
# 1     [[0.00018628025157379805, 0.000119883770228491...
# 1     [[0.00018628025157379805, 0.000119883770228491...
# 2     [[0.0001861334885753973, 0.0001196096846780689...
# ...                                                 ...
# 6296  [[0.00012539998182513627, 0.000103161388526744...
# 6297  [[0.00012626156054781397, 0.000103786999700811...
# 6297  [[0.00012626156054781397, 0.000103786999700811...
# 6298  [[0.00012634548004045128, 0.000103893442941983...
# 6298  [[0.00012634548004045128, 0.000103893442941983...
#
#                                             return_list
# 0     tic              NDX       SPX
# date           ...
# 0     tic              NDX       SPX
# date           ...
# 1     tic              NDX       SPX
# date           ...
# 1     tic              NDX       SPX
# date           ...
# 2     tic              NDX       SPX
# date           ...
# ...                                                 ...
# 6296  tic              NDX       SPX
# date           ...
# 6297  tic              NDX       SPX
# date           ...
# 6297  tic              NDX       SPX
# date           ...
# 6298  tic              NDX       SPX
# date           ...
# 6298  tic              NDX       SPX
# date           ...
#
# [12598 rows x 33 columns]

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 2

# %%
df.equals(loadeddf)
# Out:
# False

# %%
# differences = df.compare(loadeddf)

# %%
print(df.dtypes)
# Out:
# date              datetime64[ns]
# close                    float64
# open                     float64
# low                      float64
# high                     float64
# RSI14                    float64
# RSI30                    float64
# RSI3                     float64
# MA200                    float64
# MA50                     float64
# MA20                     float64
# tic                       object
# PUT Index                float64
# RXM Index                float64
# USGG2YR Index            float64
# USGG10YR Index           float64
# MOVE Index               float64
# VIX Index                float64
# NWHLSENY Index           float64
# NWHLSEND Index           float64
# USGG5YR Index            float64
# SFFRNEWS Index           float64
# US10-US2Y                float64
# macd                     float64
# boll_ub                  float64
# boll_lb                  float64
# rsi_30                   float64
# cci_30                   float64
# dx_30                    float64
# close_30_sma             float64
# close_60_sma             float64
# cov_list                  object
# return_list               object
# dtype: object

# %%
print(loadeddf.dtypes)
# Out:
# date              datetime64[ns]
# close                    float64
# open                     float64
# low                      float64
# high                     float64
# RSI14                    float64
# RSI30                    float64
# RSI3                     float64
# MA200                    float64
# MA50                     float64
# MA20                     float64
# tic                       object
# PUT Index                float64
# RXM Index                float64
# USGG2YR Index            float64
# USGG10YR Index           float64
# MOVE Index               float64
# VIX Index                float64
# NWHLSENY Index           float64
# NWHLSEND Index           float64
# USGG5YR Index            float64
# SFFRNEWS Index           float64
# US10-US2Y                float64
# macd                     float64
# boll_ub                  float64
# boll_lb                  float64
# rsi_30                   float64
# cci_30                   float64
# dx_30                    float64
# close_30_sma             float64
# close_60_sma             float64
# cov_list                  object
# return_list               object
# dtype: object

# %%
df
# Out:
#             date     close      open       low      high  RSI14  RSI30   RSI3  \
# 0     1990-12-31    200.53    199.37    198.39    200.53  61.89  57.60  59.92
# 1     1990-12-31    330.22    328.71    327.50    330.23  59.06  55.75  60.85
# 2     1991-01-02    199.77    200.53    199.04    200.80  59.55  56.80  43.39
# 3     1991-01-02    326.45    330.20    326.45    330.75  51.04  52.78  25.54
# 4     1991-01-03    196.40    199.77    196.16    199.80  50.46  53.39  15.31
# ...          ...       ...       ...       ...       ...    ...    ...    ...
# 16401 2023-07-21   4536.34   4550.16   4535.79   4555.00  68.09  64.88  54.47
# 16402 2023-07-24  15448.02  15475.15  15374.66  15504.67  59.40  62.77  32.40
# 16403 2023-07-24   4554.64   4543.39   4541.29   4563.41  70.02  65.78  71.01
# 16404 2023-07-25  15593.47  15483.06  15482.04  15622.69  63.02  64.28  61.61
# 16405 2023-07-25   4576.77   4555.19   4552.42   4580.62  72.22  66.84  82.52
#
#           MA200      MA50  ...        macd       boll_ub       boll_lb  \
# 0        206.27    188.69  ...    3.202235    203.287066    194.326934
# 1        334.29    319.46  ...    2.924538    332.631558    324.867442
# 2        206.17    189.19  ...    2.998350    203.084732    195.053268
# 3        334.20    319.74  ...    2.504065    332.269105    325.464895
# 4        206.06    189.55  ...    2.535609    202.994417    195.222583
# ...         ...       ...  ...         ...           ...           ...
# 16401   4052.70   4327.99  ...   61.647135   4594.093122   4310.236878
# 16402  12651.90  14692.16  ...  257.405842  15916.201353  14642.568647
# 16403   4056.52   4336.33  ...   61.499949   4602.610732   4322.350268
# 16404  12672.00  14736.23  ...  250.099106  15911.393328  14737.821672
# 16405   4060.49   4345.26  ...   62.449134   4608.960684   4340.795316
#
#           rsi_30      cci_30      dx_30  close_30_sma  close_60_sma  \
# 0      57.597757   66.601015  18.220983    194.914333    185.697333
# 1      55.748933   60.380411   7.442287    324.969667    316.762167
# 2      56.796107   64.214464  19.192477    195.408000    186.054000
# 3      52.782480   39.120709   3.249934    325.280667    317.011333
# 4      53.387634   28.543660   4.973436    195.720000    186.334667
# ...          ...         ...        ...           ...           ...
# 16401  64.877680  130.895366  39.904326   4422.944667   4293.225333
# 16402  62.769705   73.110558  20.580513  15164.923333  14441.190833
# 16403  65.775789  130.724267  41.563408   4431.635000   4301.536167
# 16404  64.284144   96.167351  26.033977  15200.427000  14481.748167
# 16405  66.836649  135.672047  44.891475   4440.898667   4308.893167
#
#                                                 cov_list  \
# 0      [[0.00018546693822883993, 0.000119093241522192...
# 1      [[0.00018546693822883993, 0.000119093241522192...
# 2      [[0.00018533093497689402, 0.000119181747471572...
# 3      [[0.00018533093497689402, 0.000119181747471572...
# 4      [[0.00018628025157379805, 0.000119883770228491...
# ...                                                  ...
# 16401  [[0.00025269533527981687, 0.000180749914571345...
# 16402  [[0.00025197081439871704, 0.000180258717847284...
# 16403  [[0.00025197081439871704, 0.000180258717847284...
# 16404  [[0.00025086874030817355, 0.000179662211125842...
# 16405  [[0.00025086874030817355, 0.000179662211125842...
#
#                                              return_list
# 0      tic              NDX       SPX
# date           ...
# 1      tic              NDX       SPX
# date           ...
# 2      tic              NDX       SPX
# date           ...
# 3      tic              NDX       SPX
# date           ...
# 4      tic              NDX       SPX
# date           ...
# ...                                                  ...
# 16401  tic              NDX       SPX
# date           ...
# 16402  tic              NDX       SPX
# date           ...
# 16403  tic              NDX       SPX
# date           ...
# 16404  tic              NDX       SPX
# date           ...
# 16405  tic              NDX       SPX
# date           ...
#
# [16406 rows x 33 columns]

# %%
# fe = FeatureEngineer(
#                     use_technical_indicator=True,
#                     use_turbulence=False,
#                     user_defined_feature = False)

# df = fe.preprocess_data(df)
# df

# %%
df =loadeddf

# %%
df.columns
# Out:
# Index(['date', 'close', 'open', 'low', 'high', 'RSI14', 'RSI30', 'RSI3',
#        'MA200', 'MA50', 'MA20', 'tic', 'PUT Index', 'RXM Index',
#        'USGG2YR Index', 'USGG10YR Index', 'MOVE Index', 'VIX Index',
#        'NWHLSENY Index', 'NWHLSEND Index', 'USGG5YR Index', 'SFFRNEWS Index',
#        'US10-US2Y', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30',
#        'close_30_sma', 'close_60_sma', 'cov_list', 'return_list'],
#       dtype='object')

# %% [markdown]
# Old ENV kwargs

# %% [markdown]
# NEW ENV kwards for SPX vs. Cash

# %%
eco_indicator_list = ["PUT Index",
                      "RXM Index",
                      "MOVE Index",
                      "USGG30YR Index",	
                      "VIX Index",
                      "NWHLSENY Index",
                      "USGG10YR Index",	
                      "USGG5YR Index",	
                      "SFFRNEWS Index",	
                      "DXY Curncy"
]
new_tech_indics = ['RSI14', 'RSI30', 'RSI3',
       'MA200', 'MA50', 'MA20', 'PUT Index', 'RXM Index',
       'USGG2YR Index', 'USGG10YR Index', 'MOVE Index', 'VIX Index',
       'NWHLSENY Index', 'NWHLSEND Index', 'USGG5YR Index', 'SFFRNEWS Index',
       'US10-US2Y']
all_techs = ['RSI14', 'RSI30', 'RSI3',
       'MA200', 'MA50', 'MA20', 'PUT Index', 'RXM Index',
       'USGG2YR Index', 'USGG10YR Index', 'MOVE Index', 'VIX Index',
       'NWHLSENY Index', 'NWHLSEND Index', 'USGG5YR Index', 'SFFRNEWS Index',
       'US10-US2Y', 'macd', 'boll_ub', 'boll_lb',  'cci_30', 'dx_30',
       'close_30_sma', 'close_60_sma']
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension,
    # "eco_indicator_list": eco_indicator_list, 
    # "tech_indicator_list": new_tech_indics, 
    "tech_indicator_list": all_techs, 
    # "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    # "cov": False
    
}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)
# !FLO New validation set
e_validate_gym = StockPortfolioEnv(df = validate, **env_kwargs)
# Out:
# Observation space Box(-inf, inf, (26, 2), float32)
# state space 2
# Observation space Box(-inf, inf, (26, 2), float32)
# state space 2

# %%
train
# Out:
#            date    close     open      low     high  RSI14  RSI30   RSI3  \
# 0    1991-01-02   199.77   200.53   199.04   200.80  59.55  56.80  43.39
# 0    1991-01-02   326.45   330.20   326.45   330.75  51.04  52.78  25.54
# 1    1991-01-03   196.40   199.77   196.16   199.80  50.46  53.39  15.31
# 1    1991-01-03   321.91   326.46   321.90   326.53  43.40  49.50  12.47
# 2    1991-01-04   196.83   196.40   195.67   198.08  51.48  53.75  24.64
# ...         ...      ...      ...      ...      ...    ...    ...    ...
# 6296 2015-12-28  2056.50  2057.77  2044.20  2057.77  50.62  50.71  59.76
# 6297 2015-12-29  4691.08  4645.08  4644.32  4702.74  56.91  54.95  86.73
# 6297 2015-12-29  2078.36  2060.54  2060.54  2081.56  54.96  52.85  78.45
# 6298 2015-12-30  4652.01  4687.16  4651.73  4688.66  52.97  53.14  56.74
# 6298 2015-12-30  2063.36  2077.34  2061.97  2077.34  51.61  51.27  53.08
#
#         MA200     MA50  ...      macd      boll_ub      boll_lb     rsi_30  \
# 0      206.17   189.19  ...  2.998350   203.084732   195.053268  56.796107
# 0      334.20   319.74  ...  2.504065   332.269105   325.464895  52.782480
# 1      206.06   189.55  ...  2.535609   202.994417   195.222583  53.387634
# 1      334.10   319.88  ...  1.783934   333.141944   324.148056  49.501121
# 2      205.97   189.92  ...  2.178470   203.016094   194.980906  53.753968
# ...       ...      ...  ...       ...          ...          ...        ...
# 6296  2061.49  2065.14  ... -4.428211  2106.573325  2001.876675  50.713085
# 6297  4472.99  4626.90  ...  2.532235  4746.436586  4510.665414  54.950690
# 6297  2061.48  2066.04  ... -1.770284  2106.262560  2001.982440  52.849490
# 6298  4474.37  4630.69  ...  4.757756  4736.490657  4514.196343  53.141166
# 6298  2061.43  2066.63  ... -0.864269  2099.328415  2004.989585  51.271895
#
#          cci_30      dx_30  close_30_sma  close_60_sma  \
# 0     64.214464  19.192477    195.408000    186.054000
# 0     39.120709   3.249934    325.280667    317.011333
# 1     28.543660   4.973436    195.720000    186.334667
# 1    -24.893497  12.555330    325.366333    317.151833
# 2     15.716780   2.744251    196.170667    186.721333
# ...         ...        ...           ...           ...
# 6296 -25.136480   8.777923   2060.662333   2053.974667
# 6297  71.475191   0.833402   4635.317333   4582.929667
# 6297  39.320468   2.873594   2062.506333   2056.091333
# 6298  43.969731   0.833402   4638.202000   4588.272667
# 6298  16.730696   2.873594   2062.845333   2057.363167
#
#                                                cov_list  \
# 0     [[0.00018533093497689402, 0.000119181747471572...
# 0     [[0.00018533093497689402, 0.000119181747471572...
# 1     [[0.00018628025157379805, 0.000119883770228491...
# 1     [[0.00018628025157379805, 0.000119883770228491...
# 2     [[0.0001861334885753973, 0.0001196096846780689...
# ...                                                 ...
# 6296  [[0.00012539998182513627, 0.000103161388526744...
# 6297  [[0.00012626156054781397, 0.000103786999700811...
# 6297  [[0.00012626156054781397, 0.000103786999700811...
# 6298  [[0.00012634548004045128, 0.000103893442941983...
# 6298  [[0.00012634548004045128, 0.000103893442941983...
#
#                                             return_list
# 0     tic              NDX       SPX
# date           ...
# 0     tic              NDX       SPX
# date           ...
# 1     tic              NDX       SPX
# date           ...
# 1     tic              NDX       SPX
# date           ...
# 2     tic              NDX       SPX
# date           ...
# ...                                                 ...
# 6296  tic              NDX       SPX
# date           ...
# 6297  tic              NDX       SPX
# date           ...
# 6297  tic              NDX       SPX
# date           ...
# 6298  tic              NDX       SPX
# date           ...
# 6298  tic              NDX       SPX
# date           ...
#
# [12598 rows x 33 columns]

# %%
# train.to_csv("train_fails.csv")

# %%
env_train, _ = e_train_gym.get_sb_env()
#!FLO New validation set
env_validate, _ = e_validate_gym.get_sb_env()
# Out:
# /Users/floriankockler/anaconda3/envs/py310/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.

# %%
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS, tensorboard_log='/Users/floriankockler/Documents/GitHub.nosync/TrainedModels/TensorboardLogs/')
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c_etf',
                                total_timesteps=50000)
# Out:
# Logging to /Users/floriankockler/Documents/GitHub.nosync/TrainedModels/TensorboardLogs/a2c_etf_41
# -------------------------------------
# | time/                 |           |
# |    fps                | 812       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.61e+07  |
# |    reward             | 1560786.1 |
# |    std                | 0.996     |
# |    value_loss         | 2.54e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 976       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 1.51e+07  |
# |    reward             | 1602887.4 |
# |    std                | 0.991     |
# |    value_loss         | 2.77e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1028      |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 1.96e+07  |
# |    reward             | 2902492.5 |
# |    std                | 0.988     |
# |    value_loss         | 8.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1063      |
# |    iterations         | 400       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 3.21e+07  |
# |    reward             | 4896878.5 |
# |    std                | 0.989     |
# |    value_loss         | 2.48e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 500       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 5.99e+07  |
# |    reward             | 7004409.0 |
# |    std                | 0.989     |
# |    value_loss         | 5.79e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1100      |
# |    iterations         | 600       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.98e+07  |
# |    reward             | 3535878.2 |
# |    std                | 0.986     |
# |    value_loss         | 1.15e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1120      |
# |    iterations         | 700       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 4.1e+07   |
# |    reward             | 4497692.5 |
# |    std                | 0.983     |
# |    value_loss         | 2.07e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1135      |
# |    iterations         | 800       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 3.95e+07  |
# |    reward             | 5113206.5 |
# |    std                | 0.981     |
# |    value_loss         | 2.71e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1152      |
# |    iterations         | 900       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 2.28e+07  |
# |    reward             | 3431147.5 |
# |    std                | 0.981     |
# |    value_loss         | 1.32e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1164      |
# |    iterations         | 1000      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 3.74e+07  |
# |    reward             | 5151816.5 |
# |    std                | 0.98      |
# |    value_loss         | 2.75e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1171      |
# |    iterations         | 1100      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 3.83e+07  |
# |    reward             | 6141632.0 |
# |    std                | 0.98      |
# |    value_loss         | 4.29e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1181      |
# |    iterations         | 1200      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -2.79     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 8.27e+07  |
# |    reward             | 8943624.0 |
# |    std                | 0.976     |
# |    value_loss         | 7.76e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:9777985.015023489
# Sharpe:  0.5266192588416037
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1155      |
# |    iterations         | 1300      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -2.79     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 9.01e+06  |
# |    reward             | 1327621.5 |
# |    std                | 0.974     |
# |    value_loss         | 1.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1161      |
# |    iterations         | 1400      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -2.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 1.59e+07  |
# |    reward             | 1577306.1 |
# |    std                | 0.972     |
# |    value_loss         | 2.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1168      |
# |    iterations         | 1500      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -2.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 1.95e+07  |
# |    reward             | 2170139.8 |
# |    std                | 0.971     |
# |    value_loss         | 5.23e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1170      |
# |    iterations         | 1600      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -2.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 3.38e+07  |
# |    reward             | 3851395.0 |
# |    std                | 0.971     |
# |    value_loss         | 1.49e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1174      |
# |    iterations         | 1700      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -2.78     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 5.68e+07  |
# |    reward             | 7019146.0 |
# |    std                | 0.972     |
# |    value_loss         | 5.21e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1176      |
# |    iterations         | 1800      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -2.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 5.11e+07  |
# |    reward             | 4009555.0 |
# |    std                | 0.97      |
# |    value_loss         | 2.16e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1177      |
# |    iterations         | 1900      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -2.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 3.02e+07  |
# |    reward             | 4027672.2 |
# |    std                | 0.967     |
# |    value_loss         | 1.75e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1181      |
# |    iterations         | 2000      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -2.77     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 3.48e+07  |
# |    reward             | 4781736.5 |
# |    std                | 0.966     |
# |    value_loss         | 2.35e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1187      |
# |    iterations         | 2100      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -2.77     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 3.6e+07   |
# |    reward             | 5842607.0 |
# |    std                | 0.964     |
# |    value_loss         | 3.5e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1192      |
# |    iterations         | 2200      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -2.76     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 3.18e+07  |
# |    reward             | 4383013.5 |
# |    std                | 0.96      |
# |    value_loss         | 1.93e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1192      |
# |    iterations         | 2300      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -2.76     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 5.04e+07  |
# |    reward             | 4984462.5 |
# |    std                | 0.961     |
# |    value_loss         | 2.87e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1192      |
# |    iterations         | 2400      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -2.76     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 6.56e+07  |
# |    reward             | 7367537.0 |
# |    std                | 0.961     |
# |    value_loss         | 6.03e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1193      |
# |    iterations         | 2500      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -2.75     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 6.61e+07  |
# |    reward             | 9963876.0 |
# |    std                | 0.958     |
# |    value_loss         | 1.08e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:10050314.614965947
# Sharpe:  0.5299353915631214
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1174      |
# |    iterations         | 2600      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -2.75     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 1.11e+07  |
# |    reward             | 1439983.8 |
# |    std                | 0.958     |
# |    value_loss         | 2.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1178      |
# |    iterations         | 2700      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -2.75     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 1.18e+07  |
# |    reward             | 1648281.8 |
# |    std                | 0.959     |
# |    value_loss         | 2.93e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1180      |
# |    iterations         | 2800      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -2.75     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 2.8e+07   |
# |    reward             | 2699477.8 |
# |    std                | 0.955     |
# |    value_loss         | 7.94e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1177      |
# |    iterations         | 2900      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -2.75     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 3.43e+07  |
# |    reward             | 5444577.5 |
# |    std                | 0.955     |
# |    value_loss         | 2.95e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1180      |
# |    iterations         | 3000      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -2.74     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 8.86e+07  |
# |    reward             | 9955896.0 |
# |    std                | 0.953     |
# |    value_loss         | 1.07e+15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1183      |
# |    iterations         | 3100      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -2.74     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 4.59e+07  |
# |    reward             | 4946126.5 |
# |    std                | 0.951     |
# |    value_loss         | 2.59e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1181      |
# |    iterations         | 3200      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -2.73     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 5.76e+07  |
# |    reward             | 6329669.5 |
# |    std                | 0.948     |
# |    value_loss         | 4.1e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1181      |
# |    iterations         | 3300      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -2.73     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 7.57e+07  |
# |    reward             | 6783178.0 |
# |    std                | 0.949     |
# |    value_loss         | 4.87e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1180      |
# |    iterations         | 3400      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -2.73     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 7.54e+07  |
# |    reward             | 7789697.5 |
# |    std                | 0.947     |
# |    value_loss         | 6.41e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1180      |
# |    iterations         | 3500      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -2.73     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 6.51e+07  |
# |    reward             | 7014523.0 |
# |    std                | 0.946     |
# |    value_loss         | 4.86e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1183      |
# |    iterations         | 3600      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -2.73     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 5.31e+07  |
# |    reward             | 8806114.0 |
# |    std                | 0.946     |
# |    value_loss         | 8.29e+14  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1186       |
# |    iterations         | 3700       |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 18500      |
# | train/                |            |
# |    entropy_loss       | -2.73      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 3699       |
# |    policy_loss        | 1.14e+08   |
# |    reward             | 12991397.0 |
# |    std                | 0.945      |
# |    value_loss         | 1.74e+15   |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:14416616.624314219
# Sharpe:  0.6043738956488733
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1179      |
# |    iterations         | 3800      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -2.72     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 1.02e+07  |
# |    reward             | 1276376.0 |
# |    std                | 0.945     |
# |    value_loss         | 1.59e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1182      |
# |    iterations         | 3900      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -2.72     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 1.3e+07   |
# |    reward             | 1636985.4 |
# |    std                | 0.942     |
# |    value_loss         | 2.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1184      |
# |    iterations         | 4000      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -2.72     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 1.24e+07  |
# |    reward             | 1933988.1 |
# |    std                | 0.94      |
# |    value_loss         | 3.88e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1187      |
# |    iterations         | 4100      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -2.71     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 2.02e+07  |
# |    reward             | 3278042.5 |
# |    std                | 0.938     |
# |    value_loss         | 9.56e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1187      |
# |    iterations         | 4200      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -2.71     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 4.29e+07  |
# |    reward             | 6205368.5 |
# |    std                | 0.937     |
# |    value_loss         | 4.03e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1186      |
# |    iterations         | 4300      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -2.7      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 3.46e+07  |
# |    reward             | 5771757.0 |
# |    std                | 0.934     |
# |    value_loss         | 3.18e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1183      |
# |    iterations         | 4400      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -2.7      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 2.69e+07  |
# |    reward             | 3821375.8 |
# |    std                | 0.933     |
# |    value_loss         | 1.4e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1185      |
# |    iterations         | 4500      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -2.69     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 3.38e+07  |
# |    reward             | 4701839.0 |
# |    std                | 0.93      |
# |    value_loss         | 2.57e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1180      |
# |    iterations         | 4600      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -2.69     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 4.44e+07  |
# |    reward             | 5929248.0 |
# |    std                | 0.928     |
# |    value_loss         | 3.66e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1182      |
# |    iterations         | 4700      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -2.69     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 2.71e+07  |
# |    reward             | 3674704.0 |
# |    std                | 0.927     |
# |    value_loss         | 1.38e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1184      |
# |    iterations         | 4800      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -2.68     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 4.63e+07  |
# |    reward             | 6301947.0 |
# |    std                | 0.924     |
# |    value_loss         | 4.04e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1186      |
# |    iterations         | 4900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -2.68     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 5.33e+07  |
# |    reward             | 7482843.5 |
# |    std                | 0.923     |
# |    value_loss         | 5.84e+14  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1188       |
# |    iterations         | 5000       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -2.68      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 4999       |
# |    policy_loss        | 7.1e+07    |
# |    reward             | 10711143.0 |
# |    std                | 0.923      |
# |    value_loss         | 1.19e+15   |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:10754171.080026686
# Sharpe:  0.5507006689808863
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1181      |
# |    iterations         | 5100      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.68     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 1.47e+07  |
# |    reward             | 1432031.5 |
# |    std                | 0.923     |
# |    value_loss         | 2.17e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1183      |
# |    iterations         | 5200      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 1.07e+07  |
# |    reward             | 1695125.0 |
# |    std                | 0.922     |
# |    value_loss         | 3.04e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1185      |
# |    iterations         | 5300      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.53e+07  |
# |    reward             | 2465161.8 |
# |    std                | 0.919     |
# |    value_loss         | 6.46e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1186      |
# |    iterations         | 5400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.48e+07  |
# |    reward             | 4058506.0 |
# |    std                | 0.918     |
# |    value_loss         | 1.7e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1187      |
# |    iterations         | 5500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 6.39e+07  |
# |    reward             | 8294866.0 |
# |    std                | 0.917     |
# |    value_loss         | 7.27e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1188      |
# |    iterations         | 5600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 2.99e+07  |
# |    reward             | 5165339.0 |
# |    std                | 0.918     |
# |    value_loss         | 2.77e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1190      |
# |    iterations         | 5700      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -2.66     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 3.35e+07  |
# |    reward             | 4859883.0 |
# |    std                | 0.916     |
# |    value_loss         | 2.49e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1191      |
# |    iterations         | 5800      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -2.66     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 4.78e+07  |
# |    reward             | 5363137.5 |
# |    std                | 0.913     |
# |    value_loss         | 3.05e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1193      |
# |    iterations         | 5900      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -2.65     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 4.79e+07  |
# |    reward             | 5632920.5 |
# |    std                | 0.912     |
# |    value_loss         | 3.31e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1194      |
# |    iterations         | 6000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -2.65     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 2.86e+07  |
# |    reward             | 5031276.0 |
# |    std                | 0.912     |
# |    value_loss         | 2.94e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1196      |
# |    iterations         | 6100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -2.65     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 5.88e+07  |
# |    reward             | 6366321.0 |
# |    std                | 0.912     |
# |    value_loss         | 4.12e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1197      |
# |    iterations         | 6200      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -2.65     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 5.58e+07  |
# |    reward             | 9154116.0 |
# |    std                | 0.91      |
# |    value_loss         | 8.85e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:10774247.921315296
# Sharpe:  0.5512858091427941
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1192      |
# |    iterations         | 6300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -2.64     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 8.09e+07  |
# |    reward             | 955089.7  |
# |    std                | 0.904     |
# |    value_loss         | 1.24e+15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1193      |
# |    iterations         | 6400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -2.63     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.13e+07  |
# |    reward             | 1514526.2 |
# |    std                | 0.9       |
# |    value_loss         | 2.43e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1193      |
# |    iterations         | 6500      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -2.63     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6499      |
# |    policy_loss        | 9.93e+06  |
# |    reward             | 1613159.9 |
# |    std                | 0.9       |
# |    value_loss         | 2.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1194      |
# |    iterations         | 6600      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -2.63     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.48e+07  |
# |    reward             | 2855391.2 |
# |    std                | 0.9       |
# |    value_loss         | 8.8e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1194      |
# |    iterations         | 6700      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -2.62     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6699      |
# |    policy_loss        | 4.47e+07  |
# |    reward             | 5232682.5 |
# |    std                | 0.898     |
# |    value_loss         | 2.77e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1195      |
# |    iterations         | 6800      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -2.62     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6799      |
# |    policy_loss        | 7.08e+07  |
# |    reward             | 7434601.0 |
# |    std                | 0.897     |
# |    value_loss         | 6.45e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1196      |
# |    iterations         | 6900      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -2.62     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6899      |
# |    policy_loss        | 2.45e+07  |
# |    reward             | 4466944.5 |
# |    std                | 0.896     |
# |    value_loss         | 1.97e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1197      |
# |    iterations         | 7000      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -2.61     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6999      |
# |    policy_loss        | 4.52e+07  |
# |    reward             | 6026682.0 |
# |    std                | 0.894     |
# |    value_loss         | 3.81e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 7100      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -2.61     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7099      |
# |    policy_loss        | 5.66e+07  |
# |    reward             | 7167830.0 |
# |    std                | 0.894     |
# |    value_loss         | 5.26e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 7200      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -2.61     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7199      |
# |    policy_loss        | 3.36e+07  |
# |    reward             | 4662918.5 |
# |    std                | 0.894     |
# |    value_loss         | 2.56e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 7300      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -2.61     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7299      |
# |    policy_loss        | 6.06e+07  |
# |    reward             | 6955971.0 |
# |    std                | 0.893     |
# |    value_loss         | 4.93e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1199      |
# |    iterations         | 7400      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -2.61     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 8.23e+07  |
# |    reward             | 8298500.5 |
# |    std                | 0.892     |
# |    value_loss         | 7.34e+14  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1200       |
# |    iterations         | 7500       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -2.6       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 7499       |
# |    policy_loss        | 7.8e+07    |
# |    reward             | 12316130.0 |
# |    std                | 0.89       |
# |    value_loss         | 1.51e+15   |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:13308784.396228066
# Sharpe:  0.5951030233699091
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1196      |
# |    iterations         | 7600      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -2.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7599      |
# |    policy_loss        | 1.02e+07  |
# |    reward             | 1259835.6 |
# |    std                | 0.889     |
# |    value_loss         | 1.75e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1197      |
# |    iterations         | 7700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -2.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 1.06e+07  |
# |    reward             | 1637945.9 |
# |    std                | 0.888     |
# |    value_loss         | 2.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 7800      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -2.6      |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 1.2e+07   |
# |    reward             | 2107337.2 |
# |    std                | 0.889     |
# |    value_loss         | 4.99e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1199      |
# |    iterations         | 7900      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -2.59     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 2.43e+07  |
# |    reward             | 3662704.2 |
# |    std                | 0.885     |
# |    value_loss         | 1.47e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1200      |
# |    iterations         | 8000      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -2.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 5.28e+07  |
# |    reward             | 6143693.0 |
# |    std                | 0.886     |
# |    value_loss         | 4.36e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1201      |
# |    iterations         | 8100      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -2.59     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 4.42e+07  |
# |    reward             | 3946186.8 |
# |    std                | 0.884     |
# |    value_loss         | 2e+14     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1202      |
# |    iterations         | 8200      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -2.59     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 2.32e+07  |
# |    reward             | 4401777.0 |
# |    std                | 0.882     |
# |    value_loss         | 1.96e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1203      |
# |    iterations         | 8300      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -2.58     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 3.38e+07  |
# |    reward             | 5220762.5 |
# |    std                | 0.88      |
# |    value_loss         | 2.85e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1204      |
# |    iterations         | 8400      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -2.58     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 5.01e+07  |
# |    reward             | 6238971.5 |
# |    std                | 0.877     |
# |    value_loss         | 4.19e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1204      |
# |    iterations         | 8500      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -2.58     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 3.53e+07  |
# |    reward             | 4636344.0 |
# |    std                | 0.877     |
# |    value_loss         | 2.42e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1204      |
# |    iterations         | 8600      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -2.57     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 5.68e+07  |
# |    reward             | 5885722.5 |
# |    std                | 0.876     |
# |    value_loss         | 3.6e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1203      |
# |    iterations         | 8700      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -2.57     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8699      |
# |    policy_loss        | 5.48e+07  |
# |    reward             | 8402642.0 |
# |    std                | 0.876     |
# |    value_loss         | 7.53e+14  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1204       |
# |    iterations         | 8800       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -2.58      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 8799       |
# |    policy_loss        | 7.32e+07   |
# |    reward             | 11279517.0 |
# |    std                | 0.877      |
# |    value_loss         | 1.37e+15   |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:11409559.176070172
# Sharpe:  0.5662252633422368
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 8900      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -2.57     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 1.12e+07  |
# |    reward             | 1401189.0 |
# |    std                | 0.876     |
# |    value_loss         | 2.18e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 9000      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -2.57     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 1.04e+07  |
# |    reward             | 1642807.2 |
# |    std                | 0.874     |
# |    value_loss         | 2.77e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 9100      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -2.57     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 1.98e+07  |
# |    reward             | 2524106.0 |
# |    std                | 0.874     |
# |    value_loss         | 6.94e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1198      |
# |    iterations         | 9200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -2.56     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 3.71e+07  |
# |    reward             | 5292057.5 |
# |    std                | 0.872     |
# |    value_loss         | 2.78e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1196      |
# |    iterations         | 9300      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -2.56     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 5.7e+07   |
# |    reward             | 9218589.0 |
# |    std                | 0.871     |
# |    value_loss         | 8.56e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1195      |
# |    iterations         | 9400      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -2.56     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 2.19e+07  |
# |    reward             | 3553850.8 |
# |    std                | 0.87      |
# |    value_loss         | 1.44e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1194      |
# |    iterations         | 9500      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -2.56     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 3.89e+07  |
# |    reward             | 4601577.5 |
# |    std                | 0.87      |
# |    value_loss         | 2.43e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1192      |
# |    iterations         | 9600      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -2.55     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 4.52e+07  |
# |    reward             | 5146800.0 |
# |    std                | 0.868     |
# |    value_loss         | 2.74e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1191      |
# |    iterations         | 9700      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -2.55     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 4.72e+07  |
# |    reward             | 5818392.0 |
# |    std                | 0.867     |
# |    value_loss         | 4e+14     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1191      |
# |    iterations         | 9800      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -2.55     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 4.46e+07  |
# |    reward             | 5385497.0 |
# |    std                | 0.865     |
# |    value_loss         | 3.06e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1191      |
# |    iterations         | 9900      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -2.54     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 5.07e+07  |
# |    reward             | 6889312.5 |
# |    std                | 0.863     |
# |    value_loss         | 4.89e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1191      |
# |    iterations         | 10000     |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -2.54     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 6.76e+07  |
# |    reward             | 9972314.0 |
# |    std                | 0.863     |
# |    value_loss         | 1.05e+15  |
# -------------------------------------

# %% [markdown]
# Optimize

# %%
# optimize(e_validate_gym,env_train, n_trial_runs=10)

# %%
# trained_a2c.save('/Users/floriankockler/Documents/GitHub.nosync/TrainedModels//trained_a2c_etf.zip')

# %% [markdown]
# Trading

# %%
trade = data_split(df,bbg_validate_start_date, bbg_validate_end_date)
e_validate_gym = StockPortfolioEnv(df = validate, **env_kwargs)
# Out:
# Observation space Box(-inf, inf, (26, 2), float32)
# state space 2

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_validate_gym)
# Out:
# /Users/floriankockler/anaconda3/envs/py310/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:2311464.088048219
# Sharpe:  0.9272717315572083
# =================================
# hit end!

# %%
df_actions.to_csv('df_actions.csv')
df_actions
# Out:
#             NDX  SPX
# date
# 2016-01-04  0.5  0.5
# 2016-01-05  0.5  0.5
# 2016-01-06  0.5  0.5
# 2016-01-07  0.5  0.5
# 2016-01-08  0.5  0.5
# ...         ...  ...
# 2020-12-23  0.5  0.5
# 2020-12-24  0.5  0.5
# 2020-12-28  0.5  0.5
# 2020-12-29  0.5  0.5
# 2020-12-30  0.5  0.5
#
# [1258 rows x 2 columns]

# %% [markdown]
# Backtest

# %%
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats 
perf_stats_all = perf_func( returns=DRL_strat, 
                              factor_returns=DRL_strat, 
                                positions=None, transactions=None, turnover_denom="AGB")

# %%
df_daily_return
# Out:
#            date  daily_return
# 0    2016-01-04      0.000000
# 1    2016-01-05     -0.000515
# 2    2016-01-06     -0.011040
# 3    2016-01-07     -0.027405
# 4    2016-01-08     -0.009478
# ...         ...           ...
# 1253 2020-12-23     -0.002160
# 1254 2020-12-24      0.004055
# 1255 2020-12-28      0.009390
# 1256 2020-12-29     -0.000933
# 1257 2020-12-30      0.000744
#
# [1258 rows x 2 columns]

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return           0.182750
# Cumulative returns      1.311464
# Annual volatility       0.203527
# Sharpe ratio            0.927272
# Calmar ratio            0.590214
# Stability               0.928607
# Max drawdown           -0.309634
# Omega ratio             1.211431
# Sortino ratio           1.287132
# Skew                   -0.647886
# Kurtosis               16.010025
# Tail ratio              0.924852
# Daily value at risk    -0.024893
# Alpha                   0.000000
# Beta                    1.000000
# dtype: float64

# %%
# %matplotlib inline
# show_weight_distribution(df_actions)

# %% [markdown]
# Baselinestats

# %%
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^SPX", 
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1257, 8)
# Annual return          0.131479
# Cumulative returns     0.851798
# Annual volatility      0.192397
# Sharpe ratio           0.739502
# Calmar ratio           0.387558
# Stability              0.882352
# Max drawdown          -0.339250
# Omega ratio            1.173105
# Sortino ratio          1.017377
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.854454
# Daily value at risk   -0.023675
# dtype: float64

# %%
# %matplotlib inline
baseline_df = get_baseline(
        ticker='^SPX', start=df_daily_return.loc[0,'date'], end='2023-06-29'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
        
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1884, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>59</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>18.275%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>131.146%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>20.353%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.963%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.21</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.65</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>16.01</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.489%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.04</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30.96</td>
#       <td>2020-02-19</td>
#       <td>2020-03-23</td>
#       <td>2020-07-06</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>21.21</td>
#       <td>2018-10-01</td>
#       <td>2018-12-24</td>
#       <td>2019-04-18</td>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11.19</td>
#       <td>2020-09-02</td>
#       <td>2020-09-23</td>
#       <td>2020-11-27</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.51</td>
#       <td>2016-01-04</td>
#       <td>2016-02-11</td>
#       <td>2016-03-21</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10.18</td>
#       <td>2018-01-26</td>
#       <td>2018-02-08</td>
#       <td>2018-06-14</td>
#       <td>100</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.07%</td>
#       <td>-4.00%</td>
#       <td>3.25%</td>
#     </tr>
#     <tr>
#       <th>Covid</th>
#       <td>0.12%</td>
#       <td>-12.09%</td>
#       <td>9.68%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Trading

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension,
    # "eco_indicator_list": eco_indicator_list, 
    # "tech_indicator_list": new_tech_indics, 
    "tech_indicator_list": all_techs, 
    # "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    # "cov": False
    
}
e_test_gym = StockPortfolioEnv(df = test, **env_kwargs)
# Out:
# Observation space Box(-inf, inf, (26, 2), float32)
# state space 2

# %%
# optimized_a2c = agent.train_model(model=model_a2c, 
#                                 tb_log_name='a2c_etf',
#                                 total_timesteps=50000)

# %%
#Params from Optimizer
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension,
    # "eco_indicator_list": eco_indicator_list, 
    # "tech_indicator_list": new_tech_indics, 
    "tech_indicator_list": all_techs, 
    # "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 3.592254438135163e-05,
    # "cov": False
    
}
A2C_PARAMS_Optimized = {

    "learning_rate": 0.0004971341790917652,
    "n_steps": 30,
    "gamma": 0.916282082006916,
    "gae_lambda": 0.8012238358841213,
    "ent_coef": 0.001972952970777057,
    "vf_coef": 0.3380424108172147,
    "max_grad_norm": 0.2221179836522716,
    # "reward_scaling": 3.592254438135163e-05,
    # "lookback": 420,
}
e_test_gym = StockPortfolioEnv(df = test, **env_kwargs)
# Out:
# Observation space Box(-inf, inf, (26, 2), float32)
# state space 2

# %%
env_test, _ = e_test_gym.get_sb_env()
agent = DRLAgent(env = env_test)
model_a2c_optimized = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS_Optimized, tensorboard_log='/Users/floriankockler/Documents/GitHub.nosync/TrainedModels/TensorboardLogs/')
# Out:
# {'learning_rate': 0.0004971341790917652, 'n_steps': 30, 'gamma': 0.916282082006916, 'gae_lambda': 0.8012238358841213, 'ent_coef': 0.001972952970777057, 'vf_coef': 0.3380424108172147, 'max_grad_norm': 0.2221179836522716}
# Using cpu device
# /Users/floriankockler/anaconda3/envs/py310/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_test_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1227743.9812218742
# Sharpe:  0.48260840517617204
# =================================
# hit end!

# %%
df_actions
# Out:
#             NDX  SPX
# date
# 2021-01-04  0.5  0.5
# 2021-01-05  0.5  0.5
# 2021-01-06  0.5  0.5
# 2021-01-07  0.5  0.5
# 2021-01-08  0.5  0.5
# ...         ...  ...
# 2023-07-18  0.5  0.5
# 2023-07-19  0.5  0.5
# 2023-07-20  0.5  0.5
# 2023-07-21  0.5  0.5
# 2023-07-24  0.5  0.5
#
# [642 rows x 2 columns]

# %%
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats 
perf_stats_all = perf_func( returns=DRL_strat, 
                              factor_returns=DRL_strat, 
                                positions=None, transactions=None, turnover_denom="AGB")

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.083869
# Cumulative returns     0.227744
# Annual volatility      0.214583
# Sharpe ratio           0.482608
# Calmar ratio           0.275507
# Stability              0.080099
# Max drawdown          -0.304418
# Omega ratio            1.084365
# Sortino ratio          0.687527
# Skew                  -0.115814
# Kurtosis               1.290554
# Tail ratio             1.031224
# Daily value at risk   -0.026624
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
# %matplotlib inline
show_weight_distribution(df_actions)

# %%
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^SPX", 
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (641, 8)
# Annual return          0.083338
# Cumulative returns     0.225822
# Annual volatility      0.184091
# Sharpe ratio           0.527564
# Calmar ratio           0.327779
# Stability              0.025701
# Max drawdown          -0.254251
# Omega ratio            1.093309
# Sortino ratio          0.752319
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.996090
# Daily value at risk   -0.022808
# dtype: float64

# %%
# %matplotlib inline
baseline_df = get_baseline(
        ticker='^SPX', start=df_daily_return.loc[0,'date'], end='2023-06-29'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
        
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (625, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-06-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>29</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.065%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>18.449%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>21.667%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.442%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.11</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.693%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.14</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30.44</td>
#       <td>2021-12-27</td>
#       <td>2022-10-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.01</td>
#       <td>2021-02-12</td>
#       <td>2021-03-04</td>
#       <td>2021-04-05</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.37</td>
#       <td>2021-09-03</td>
#       <td>2021-10-04</td>
#       <td>2021-10-26</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.24</td>
#       <td>2021-04-29</td>
#       <td>2021-05-12</td>
#       <td>2021-06-10</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.30</td>
#       <td>2021-11-19</td>
#       <td>2021-12-03</td>
#       <td>2021-12-27</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_matplotlib/tools.py:410, in handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     406 for ax in axarr:
#     407     # only the last row of subplots should get x labels -> all
#     408     # other off layout handles the case that the subplot is
#     409     # the last in the column, because below is no subplot/gap.
# --> 410     if not layout[row_num(ax) + 1, col_num(ax)]:
#     411         continue
#
# IndexError: index 12 is out of bounds for axis 0 with size 12
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[275], line 9
#       6 baseline_returns = get_daily_return(baseline_df, value_col_name="close")
#       8 with pyfolio.plotting.plotting_context(font_scale=1.1):
# ----> 9         pyfolio.create_full_tear_sheet(returns = DRL_strat,
#      10
#      11                                        benchmark_rets=baseline_returns, set_context=False)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pyfolio/tears.py:199, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     191     returns = txn.adjust_returns_for_slippage(
#     192         returns, positions, transactions, slippage
#     193     )
#     195 positions = utils.check_intraday(
#     196     estimate_intraday, returns, positions, transactions
#     197 )
# --> 199 create_returns_tear_sheet(
#     200     returns,
#     201     positions=positions,
#     202     transactions=transactions,
#     203     live_start_date=live_start_date,
#     204     cone_std=cone_std,
#     205     benchmark_rets=benchmark_rets,
#     206     bootstrap=bootstrap,
#     207     turnover_denom=turnover_denom,
#     208     header_rows=header_rows,
#     209     set_context=set_context,
#     210 )
#     212 create_interesting_times_tear_sheet(
#     213     returns, benchmark_rets=benchmark_rets, set_context=set_context
#     214 )
#     216 if positions is not None:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pyfolio/plotting.py:53, in customize.<locals>.call_w_context(*args, **kwargs)
#      51         return func(*args, **kwargs)
#      52 else:
# ---> 53     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pyfolio/tears.py:635, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     632 plotting.plot_drawdown_underwater(returns=returns, ax=ax_underwater)
#     634 plotting.plot_monthly_returns_heatmap(returns, ax=ax_monthly_heatmap)
# --> 635 plotting.plot_annual_returns(returns, ax=ax_annual_returns)
#     636 plotting.plot_monthly_returns_dist(returns, ax=ax_monthly_dist)
#     638 plotting.plot_return_quantiles(
#     639     returns, live_start_date=live_start_date, ax=ax_return_quantiles
#     640 )
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pyfolio/plotting.py:226, in plot_annual_returns(returns, ax, **kwargs)
#     217 ann_ret_df = pd.DataFrame(ep.aggregate_returns(returns, "yearly"))
#     219 ax.axvline(
#     220     100 * ann_ret_df.values.mean(),
#     221     color="red",
#    (...)
#     224     alpha=0.7,
#     225 )
# --> 226 (100 * ann_ret_df.sort_index(ascending=False)).plot(
#     227     ax=ax, kind="barh", alpha=0.70, **kwargs
#     228 )
#     229 ax.axvline(0.0, color="black", linestyle="-", lw=2)
#     231 ax.set_ylabel("Year")
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:451, in MPLPlot.generate(self)
#     449 self._add_table()
#     450 self._make_legend()
# --> 451 self._adorn_subplots()
#     453 for ax in self.axes:
#     454     self._post_plot_logic_common(ax, self.data)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:676, in MPLPlot._adorn_subplots(self)
#     674     all_axes = self._get_subplots()
#     675     nrows, ncols = self._get_axes_layout()
# --> 676     handle_shared_axes(
#     677         axarr=all_axes,
#     678         nplots=len(all_axes),
#     679         naxes=nrows * ncols,
#     680         nrows=nrows,
#     681         ncols=ncols,
#     682         sharex=self.sharex,
#     683         sharey=self.sharey,
#     684     )
#     686 for ax in self.axes:
#     687     ax = getattr(ax, "right_ax", ax)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_matplotlib/tools.py:423, in handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     421                 continue
#     422             if sharex or _has_externally_shared_axis(ax, "x"):
# --> 423                 _remove_labels_from_axis(ax.xaxis)
#     425 if ncols > 1:
#     426     for ax in axarr:
#     427         # only the first column should get y labels -> set all other to
#     428         # off as we only have labels in the first column and we always
#     429         # have a subplot there, we can skip the layout test
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/plotting/_matplotlib/tools.py:327, in _remove_labels_from_axis(axis)
#     325 if isinstance(axis.get_minor_formatter(), ticker.NullFormatter):
#     326     axis.set_minor_formatter(ticker.FormatStrFormatter(""))
# --> 327 for t in axis.get_minorticklabels():
#     328     t.set_visible(False)
#     330 axis.get_label().set_visible(False)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/axis.py:1421, in Axis.get_minorticklabels(self)
#    1419 def get_minorticklabels(self):
#    1420     """Return this Axis' minor tick labels, as a list of `~.text.Text`."""
# -> 1421     self._update_ticks()
#    1422     ticks = self.get_minor_ticks()
#    1423     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/axis.py:1263, in Axis._update_ticks(self)
#    1258 """
#    1259 Update ticks (position and labels) using the current data interval of
#    1260 the axes.  Return the list of ticks that will be drawn.
#    1261 """
#    1262 major_locs = self.get_majorticklocs()
# -> 1263 major_labels = self.major.formatter.format_ticks(major_locs)
#    1264 major_ticks = self.get_major_ticks(len(major_locs))
#    1265 self.major.formatter.set_locs(major_locs)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/ticker.py:218, in Formatter.format_ticks(self, values)
#     216 """Return the tick labels for all the ticks at once."""
#     217 self.set_locs(values)
# --> 218 return [self(value, i) for i, value in enumerate(values)]
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/ticker.py:218, in <listcomp>(.0)
#     216 """Return the tick labels for all the ticks at once."""
#     217 self.set_locs(values)
# --> 218 return [self(value, i) for i, value in enumerate(values)]
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/dates.py:990, in AutoDateFormatter.__call__(self, x, pos)
#     988 if isinstance(fmt, str):
#     989     self._formatter = DateFormatter(fmt, self._tz, usetex=self._usetex)
# --> 990     result = self._formatter(x, pos)
#     991 elif callable(fmt):
#     992     result = fmt(x, pos)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/dates.py:651, in DateFormatter.__call__(self, x, pos)
#     650 def __call__(self, x, pos=0):
# --> 651     result = num2date(x, self.tz).strftime(self.fmt)
#     652     return _wrap_in_tex(result) if self._usetex else result
#
# KeyboardInterrupt:
